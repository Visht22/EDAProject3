# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
#loading data
data=pd.read_csv("student-dataset.csv")

# %%
#step1: Understanding the data(accesing first five rows here)
data.head()
# Out:
#    id             name               nationality                 city  \
# 0   0        Kiana Lor                     China               Suzhou
# 1   1   Joshua Lonaker  United States of America        Santa Clarita
# 2   2    Dakota Blanco  United States of America              Oakland
# 3   3  Natasha Yarusso  United States of America        Castro Valley
# 4   4   Brooke Cazares                    Brazil  São José dos Campos
#
#    latitude  longitude gender  ethnic.group  age  english.grade  math.grade  \
# 0     31.31     120.62      F           NaN   22            3.5         3.7
# 1     34.39    -118.54      M           NaN   22            2.9         3.2
# 2     37.80    -122.27      F           NaN   22            3.9         3.8
# 3     37.69    -122.09      F           NaN   20            3.3         2.8
# 4    -23.18     -45.88      F           NaN   21            3.7         2.6
#
#    sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# ...

# %%
#to check the bottom 10 rows of data
data.tail(10)
# Out:
#       id                  name               nationality         city  \
# 297  297            Cody Smith  United States of America    Charlotte
# 298  298          Nicolas Papp  United States of America     New York
# 299  299  Christopher Inhulsen  United States of America   Fort Worth
# 300  300       Tessa Rawanduzy  United States of America        Derby
# 301  301      Vanessa Gonzalez                 Nicaragua         León
# 302  302           Austin Haas  United States of America     Columbus
# 303  303       Madison Fithian  United States of America  Los Angeles
# 304  304     Zachary Mulvahill  United States of America  Los Angeles
# 305  305      Eliana Michelsen  United States of America      Oakland
# 306  306       Dane Whittemore                    Canada      Toronto
#
#      latitude  longitude gender  ethnic.group  age  english.grade  math.grade  \
# 297     35.23     -80.84      M           NaN   23            3.8         3.5
# ...

# %%
#to check the no of rows and columns in data
data.shape
# Out:
# (307, 16)

# %%
print("Number of Rows", data.shape[0])
print("Number of Columns", data.shape[1])
# Out:
# Number of Rows 307
# Number of Columns 16

# %%
#data in detail description
data.describe()
# Out:
#                id    latitude   longitude  ethnic.group         age  \
# count  307.000000  307.000000  307.000000           0.0  307.000000
# mean   153.000000   32.863388  -64.539121           NaN   21.964169
# std     88.767487   13.498582   81.249146           NaN    1.248013
# min      0.000000  -33.450000 -123.130000           NaN   19.000000
# 25%     76.500000   32.720000 -118.240000           NaN   21.000000
# 50%    153.000000   34.390000  -99.140000           NaN   22.000000
# 75%    229.500000   38.960000  -73.855000           NaN   23.000000
# max    306.000000   59.890000  139.750000           NaN   26.000000
#
#        english.grade  math.grade  sciences.grade  language.grade  \
# count     307.000000  307.000000      307.000000      307.000000
# mean        3.369707    3.414332        3.446580        4.396417
# std         0.538724    0.476839        0.509081        0.996474
# min         1.500000    2.100000        1.400000        1.000000
# ...

# %%
 #to check the columns in data
data.columns
# Out:
# Index(['id', 'name', 'nationality', 'city', 'latitude', 'longitude', 'gender',
#        'ethnic.group', 'age', 'english.grade', 'math.grade', 'sciences.grade',
#        'language.grade', 'portfolio.rating', 'coverletter.rating',
#        'refletter.rating'],
#       dtype='object')

# %%
#to check the unique values in Data
data.nunique()
# Out:
# id                    307
# name                  307
# nationality            31
# city                  161
# latitude              156
# longitude             158
# gender                  3
# ethnic.group            0
# age                     8
# english.grade          25
# math.grade             20
# sciences.grade         24
# language.grade          6
# portfolio.rating        5
# coverletter.rating      6
# refletter.rating        5
# dtype: int64

# %%
data['gender'].unique()
# Out:
# array(['F', 'M', 'other'], dtype=object)

# %%
#step2: Cleaning the Data
data.isnull().sum()
# Out:
# id                      0
# name                    0
# nationality             0
# city                    0
# latitude                0
# longitude               0
# gender                  0
# ethnic.group          307
# age                     0
# english.grade           0
# math.grade              0
# sciences.grade          0
# language.grade          0
# portfolio.rating        0
# coverletter.rating      0
# refletter.rating        0
# dtype: int64

# %%
#deleting the columns which contains null values 
student=data.drop(['ethnic.group'], axis=1)

# %%
student.isnull().sum()
# Out:
# id                    0
# name                  0
# nationality           0
# city                  0
# latitude              0
# longitude             0
# gender                0
# age                   0
# english.grade         0
# math.grade            0
# sciences.grade        0
# language.grade        0
# portfolio.rating      0
# coverletter.rating    0
# refletter.rating      0
# dtype: int64

# %%
#Analysing Data Using correlation relationship
student.columns
# Out:
# Index(['id', 'name', 'nationality', 'city', 'latitude', 'longitude', 'gender',
#        'age', 'english.grade', 'math.grade', 'sciences.grade',
#        'language.grade', 'portfolio.rating', 'coverletter.rating',
#        'refletter.rating'],
#       dtype='object')

# %%
sns.heatmap(student.corr())
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9928\2311584413.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(student.corr())
# <Axes: >

# %%
cols_plot=student.columns[8:12].tolist() + ['gender']
sns.pairplot(student[cols_plot], hue='gender')

# %%
sns.relplot(x='english.grade', y='math.grade', hue='gender', data=student)

# %%
sns.histplot(student['math.grade'],color='green', bins=5)
# Out:
# <Axes: xlabel='math.grade', ylabel='Count'>

# %%
sns.histplot(student['english.grade'], bins=5)
# Out:
# <Axes: xlabel='english.grade', ylabel='Count'>

# %%
sns.histplot(student['sciences.grade'],color='green', bins=5)
# Out:
# <Axes: xlabel='sciences.grade', ylabel='Count'>

# %%
sns.histplot(student['language.grade'],color='green', bins=5)
# Out:
# <Axes: xlabel='language.grade', ylabel='Count'>

# %%
student.columns
# Out:
# Index(['id', 'name', 'nationality', 'city', 'latitude', 'longitude', 'gender',
#        'age', 'english.grade', 'math.grade', 'sciences.grade',
#        'language.grade', 'portfolio.rating', 'coverletter.rating',
#        'refletter.rating'],
#       dtype='object')

# %%
sns.catplot(x='portfolio.rating', kind='violin', color='orange', data=student)

# %%
sns.catplot(x='coverletter.rating', kind='violin', color='orange', data=student)

# %%
sns.catplot(x='refletter.rating', kind='violin',color='orange', data=student)
